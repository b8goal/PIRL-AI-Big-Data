# %% [markdown]
# # MNIST

# %% [markdown]
# ### MNIST 데이터 받기

# %%
import os
import sys
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import warnings
warnings.simplefilter("ignore")

mnist = input_data.read_data_sets("data/", one_hot=True)
train_data = mnist.train.images
train_label = mnist.train.labels
test_data = mnist.test.images
test_label = mnist.test.labels
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %% [markdown]
# ### MNIST 데이터 확인하기

# %%
# size of MNIST
print(train_data.shape)
print(train_label.shape)
print(test_data.shape)
print(test_label.shape)
# Out:
# (55000, 784)
# (55000, 10)
# (10000, 784)
# (10000, 10)

# %% [markdown]
# ### Data Pre-processing (데이터 전처리)

# %% [markdown]
# # Implementation (1)
#
#
# ## Loss function (손실 함수) : Cross Entropy
#
# # <center> \\( L(y_i, f(x_i; W)) = -\frac{1}{n}\sum_{i=1}^{n}\sum_{k=1} y_{i,j} log(f(x_i)_k)\\)</center>
#
#
# #### get_cross_entropy_loss 함수의 내용을 완성하세요.
# #### (Hint : (1) tf.reduce_mean(), tf.reduce_sum(), tf.log() (2) Tensor dimension에 유의 (3) log 함수 사용 시 epsilon 사용하세요.)

# %%
def get_cross_entropy_loss(y_true, y_hat, epsilon=1e-8):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('cross_entropy'):
        loss = -tf.reduce_mean(tf.reduce_sum(y_true * tf.log(y_hat + epsilon),axis=1))
        return loss

def get_accuracy(y_true, y_hat):
    """
    compute cross entropy

    Args:
        y_true: true label
        y_hat: predicted label
        epsilon: small value to prevent NaN in log

    Returns:
        cross entropy loss
    """
    with tf.name_scope('accuracy'):
        # Compare the highest indices between the predicted label and the true label
        correct_prediction = tf.equal(tf.argmax(y_hat, 1), tf.argmax(y_true, 1), name='correct_prediction')
        # Compute accuracy
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32), name='accuracy')
    return accuracy

# %% [markdown]
# ## Hyper-parameter (하이퍼 파라미터)

# %%
# Set hypyerparameters
learning_rate = 0.01
max_iter = 2000
batch_size = 100

# %% [markdown]
# # Implementation (2)
# ## Linear Classifier (선형 분류기)
#
# ## <center> \\( f(x) = W^Tx+b \\)</center>
#
# ### linear function을 완성하세요.
# ### (Hint : (1) weight, bias 선언 (2) tf.get_variable()의 initializer  (3) tf.matmul())

# %%
def fc(name, out_dim, inputs):
    """
    Args :
        Inputs : Input tensor
        out_dim : output dimension
        
    Returns:
        inputs * weight + bias
    """
    with tf.variable_scope(name):
        shp = inputs.get_shape().as_list()[1]
        initial = tf.truncated_normal([shp,out_dim],stddev=0.01)
        weight = tf.get_variable('w',initializer=initial)
        y_hat = tf.matmul(inputs,weight)
        return y_hat

# %% [markdown]
# # Implementation (3)
#
# ## Model Setting
#
# ### 1. Training data 및 Test data의 각각의 image를 한 vector로 만들어서 train_data, test_data에 각각 저장하세요.
# #### Hint) 데이터 차원.
# ### 2. Dataset로부터 받은 데이터(Image, label)를 담을 변수를 각각 x 및 y_true에 선언하세요.
# #### Hint) tf.placeholder
# ### 3. Implementation (2)에서 구현한 linear classifier 함수값과 softmax 함수를 통한 prediction 값을 y_hat에 저장하세요.
# #### Hint) tf.nn.softmax
# ### 4. 3으로부터 얻은 결과를 통해 Implementation (1)에서 구현한 loss function을 통해 얻은 loss를 cross_entropy에 저장하세요.

# %%
tf.reset_default_graph()
# Flatten data
###################################################################
#                    Implementation 3-1                           #
###################################################################
# train_data = None
# test_data = None

###################################################################
#                    Implementation 3-2                           #
###################################################################
x = tf.placeholder(tf.float32, [None, 784])
y_true = tf.placeholder(tf.float32, [None, 10])

###################################################################
#                    Implementation 3-3                          #
###################################################################
h1 = fc('layer1',512,x)
y_logits = fc('layer2',10,h1)
y_hat = tf.nn.softmax(y_logits)

###################################################################
#                    Implementation 3-4                           #
###################################################################
cross_entropy = get_cross_entropy_loss(y_true,y_hat)

# Calculate accuracy
accuracy = get_accuracy(y_true, y_hat)
# Make gradient descent op
train_step = tf.train.GradientDescentOptimizer(learning_rate).minimize(cross_entropy)

# Make op to initialize declared variable
init = tf.global_variables_initializer()

with tf.Session() as sess:
    # Initialize variables
    sess.run(init)
    
    # Training
    for step in range(max_iter):
        # Get batch data and label
        batch_x, batch_y = mnist.train.next_batch(batch_size)
        # train the network and calculate cross entropy
        _, loss = sess.run([train_step, cross_entropy], feed_dict={x: batch_x, y_true: batch_y})
        # calcualte accuracy
        acc = sess.run(accuracy, feed_dict={x: test_data, y_true: test_label})
        # print loss (cross entropy) and accuracy at every 10th step
        if (step + 1) % 10 == 0:
            print("{}th iteration, loss: {:.4f}, test accuracy: {:.4f}".format(step + 1, loss, acc))
# Out:
# 10th iteration, loss: 2.2926, test accuracy: 0.3039
# 20th iteration, loss: 2.2842, test accuracy: 0.4328
# 30th iteration, loss: 2.2728, test accuracy: 0.5030
# 40th iteration, loss: 2.2694, test accuracy: 0.5586
# 50th iteration, loss: 2.2588, test accuracy: 0.5979
# 60th iteration, loss: 2.2463, test accuracy: 0.6067
# 70th iteration, loss: 2.2442, test accuracy: 0.6030
# 80th iteration, loss: 2.2216, test accuracy: 0.5995
# 90th iteration, loss: 2.2169, test accuracy: 0.6197
# 100th iteration, loss: 2.2144, test accuracy: 0.6434
# 110th iteration, loss: 2.2029, test accuracy: 0.6493
# 120th iteration, loss: 2.1996, test accuracy: 0.6514
# 130th iteration, loss: 2.1773, test accuracy: 0.6527
# 140th iteration, loss: 2.1712, test accuracy: 0.6646
# 150th iteration, loss: 2.1440, test accuracy: 0.6772
# 160th iteration, loss: 2.1407, test accuracy: 0.6822
# 170th iteration, loss: 2.0817, test accuracy: 0.6858
# 180th iteration, loss: 2.0789, test accuracy: 0.6970
# 190th iteration, loss: 2.0562, test accuracy: 0.7017
# 200th iteration, loss: 2.0605, test accuracy: 0.7005
# 210th iteration, loss: 2.0477, test accuracy: 0.7042
# 220th iteration, loss: 2.0418, test accuracy: 0.7093
# 230th iteration, loss: 2.0165, test accuracy: 0.7134
# 240th iteration, loss: 1.9406, test accuracy: 0.7083
# 250th iteration, loss: 1.9029, test accuracy: 0.7073
# 260th iteration, loss: 1.9201, test accuracy: 0.7135
# 270th iteration, loss: 1.8960, test accuracy: 0.7102
# 280th iteration, loss: 1.8576, test accuracy: 0.7026
# 290th iteration, loss: 1.7905, test accuracy: 0.7027
# 300th iteration, loss: 1.8487, test accuracy: 0.7053
# 310th iteration, loss: 1.7764, test accuracy: 0.7046
# 320th iteration, loss: 1.7025, test accuracy: 0.7091
# 330th iteration, loss: 1.7434, test accuracy: 0.7113
# 340th iteration, loss: 1.6536, test accuracy: 0.7155
# 350th iteration, loss: 1.6849, test accuracy: 0.7162
# 360th iteration, loss: 1.5990, test accuracy: 0.7135
# 370th iteration, loss: 1.6615, test accuracy: 0.7136
# 380th iteration, loss: 1.5808, test accuracy: 0.7145
# 390th iteration, loss: 1.5882, test accuracy: 0.7188
# 400th iteration, loss: 1.4907, test accuracy: 0.7188
# 410th iteration, loss: 1.3734, test accuracy: 0.7227
# 420th iteration, loss: 1.4636, test accuracy: 0.7251
# 430th iteration, loss: 1.4676, test accuracy: 0.7302
# 440th iteration, loss: 1.4066, test accuracy: 0.7313
# 450th iteration, loss: 1.3885, test accuracy: 0.7342
# 460th iteration, loss: 1.3119, test accuracy: 0.7340
# 470th iteration, loss: 1.2205, test accuracy: 0.7334
# 480th iteration, loss: 1.2813, test accuracy: 0.7384
# 490th iteration, loss: 1.2571, test accuracy: 0.7398
# 500th iteration, loss: 1.2493, test accuracy: 0.7421
# 510th iteration, loss: 1.1912, test accuracy: 0.7503
# 520th iteration, loss: 1.1538, test accuracy: 0.7544
# 530th iteration, loss: 1.1950, test accuracy: 0.7573
# 540th iteration, loss: 1.1677, test accuracy: 0.7635
# 550th iteration, loss: 1.0723, test accuracy: 0.7666
# 560th iteration, loss: 1.0725, test accuracy: 0.7707
# 570th iteration, loss: 1.1979, test accuracy: 0.7759
# 580th iteration, loss: 1.1173, test accuracy: 0.7771
# 590th iteration, loss: 0.9268, test accuracy: 0.7817
# 600th iteration, loss: 1.0303, test accuracy: 0.7841
# 610th iteration, loss: 0.9755, test accuracy: 0.7868
# 620th iteration, loss: 1.0724, test accuracy: 0.7903
# 630th iteration, loss: 1.0357, test accuracy: 0.7896
# 640th iteration, loss: 0.9888, test accuracy: 0.7911
# 650th iteration, loss: 0.9564, test accuracy: 0.7965
# 660th iteration, loss: 0.9096, test accuracy: 0.7990
# 670th iteration, loss: 1.0025, test accuracy: 0.8027
# 680th iteration, loss: 0.9053, test accuracy: 0.8031
# 690th iteration, loss: 1.0437, test accuracy: 0.8031
# 700th iteration, loss: 0.8931, test accuracy: 0.8063
# 710th iteration, loss: 0.8440, test accuracy: 0.8091
# 720th iteration, loss: 0.8648, test accuracy: 0.8096
# 730th iteration, loss: 0.8150, test accuracy: 0.8135
# 740th iteration, loss: 0.8533, test accuracy: 0.8161
# 750th iteration, loss: 0.8559, test accuracy: 0.8191
# 760th iteration, loss: 0.8687, test accuracy: 0.8199
# 770th iteration, loss: 0.8300, test accuracy: 0.8209
# 780th iteration, loss: 0.8241, test accuracy: 0.8225
# 790th iteration, loss: 0.8387, test accuracy: 0.8227
# 800th iteration, loss: 0.9174, test accuracy: 0.8258
# 810th iteration, loss: 0.8119, test accuracy: 0.8270
# 820th iteration, loss: 0.7390, test accuracy: 0.8277
# 830th iteration, loss: 0.7761, test accuracy: 0.8296
# 840th iteration, loss: 0.7300, test accuracy: 0.8319
# 850th iteration, loss: 0.7138, test accuracy: 0.8334
# 860th iteration, loss: 0.7498, test accuracy: 0.8346
# 870th iteration, loss: 0.7768, test accuracy: 0.8362
# 880th iteration, loss: 0.6058, test accuracy: 0.8380
# 890th iteration, loss: 0.6661, test accuracy: 0.8392
# 900th iteration, loss: 0.7484, test accuracy: 0.8380
# 910th iteration, loss: 0.7222, test accuracy: 0.8379
# 920th iteration, loss: 0.7302, test accuracy: 0.8399
# 930th iteration, loss: 0.6893, test accuracy: 0.8400
# 940th iteration, loss: 0.6963, test accuracy: 0.8391
# 950th iteration, loss: 0.6782, test accuracy: 0.8418
# 960th iteration, loss: 0.7566, test accuracy: 0.8443
# 970th iteration, loss: 0.6656, test accuracy: 0.8439
# 980th iteration, loss: 0.6115, test accuracy: 0.8450
# 990th iteration, loss: 0.6202, test accuracy: 0.8457
# 1000th iteration, loss: 0.6425, test accuracy: 0.8478
# 1010th iteration, loss: 0.6038, test accuracy: 0.8478
# 1020th iteration, loss: 0.6458, test accuracy: 0.8476
# 1030th iteration, loss: 0.7618, test accuracy: 0.8485
# 1040th iteration, loss: 0.5901, test accuracy: 0.8508
# 1050th iteration, loss: 0.6326, test accuracy: 0.8505
# 1060th iteration, loss: 0.5525, test accuracy: 0.8523
# 1070th iteration, loss: 0.6400, test accuracy: 0.8536
# 1080th iteration, loss: 0.7204, test accuracy: 0.8540
# 1090th iteration, loss: 0.6541, test accuracy: 0.8548
# 1100th iteration, loss: 0.7246, test accuracy: 0.8552
# 1110th iteration, loss: 0.6051, test accuracy: 0.8558
# 1120th iteration, loss: 0.5349, test accuracy: 0.8561
# 1130th iteration, loss: 0.6219, test accuracy: 0.8560
# 1140th iteration, loss: 0.6859, test accuracy: 0.8572
# 1150th iteration, loss: 0.6185, test accuracy: 0.8581
# 1160th iteration, loss: 0.4892, test accuracy: 0.8584
# 1170th iteration, loss: 0.5380, test accuracy: 0.8587
# 1180th iteration, loss: 0.5705, test accuracy: 0.8597
# 1190th iteration, loss: 0.5139, test accuracy: 0.8606
# 1200th iteration, loss: 0.5065, test accuracy: 0.8607
# 1210th iteration, loss: 0.6158, test accuracy: 0.8608
# 1220th iteration, loss: 0.5867, test accuracy: 0.8620
# 1230th iteration, loss: 0.6068, test accuracy: 0.8626
# 1240th iteration, loss: 0.5557, test accuracy: 0.8637
# 1250th iteration, loss: 0.7137, test accuracy: 0.8632
# 1260th iteration, loss: 0.4744, test accuracy: 0.8640
# 1270th iteration, loss: 0.7067, test accuracy: 0.8647
# 1280th iteration, loss: 0.6273, test accuracy: 0.8654
# 1290th iteration, loss: 0.4839, test accuracy: 0.8648
# 1300th iteration, loss: 0.4882, test accuracy: 0.8652
# 1310th iteration, loss: 0.4872, test accuracy: 0.8656
# 1320th iteration, loss: 0.4713, test accuracy: 0.8665
# 1330th iteration, loss: 0.5998, test accuracy: 0.8659
# 1340th iteration, loss: 0.6681, test accuracy: 0.8671
# 1350th iteration, loss: 0.4853, test accuracy: 0.8671
# 1360th iteration, loss: 0.6006, test accuracy: 0.8677
# 1370th iteration, loss: 0.4890, test accuracy: 0.8683
# 1380th iteration, loss: 0.4903, test accuracy: 0.8689
# 1390th iteration, loss: 0.5751, test accuracy: 0.8695
# 1400th iteration, loss: 0.5457, test accuracy: 0.8707
# 1410th iteration, loss: 0.5087, test accuracy: 0.8714
# 1420th iteration, loss: 0.6524, test accuracy: 0.8729
# 1430th iteration, loss: 0.4062, test accuracy: 0.8736
# 1440th iteration, loss: 0.4958, test accuracy: 0.8725
# 1450th iteration, loss: 0.5072, test accuracy: 0.8717
# 1460th iteration, loss: 0.5263, test accuracy: 0.8717
# 1470th iteration, loss: 0.5643, test accuracy: 0.8723
# 1480th iteration, loss: 0.4385, test accuracy: 0.8748
# 1490th iteration, loss: 0.4990, test accuracy: 0.8736
# 1500th iteration, loss: 0.5615, test accuracy: 0.8736
# 1510th iteration, loss: 0.4805, test accuracy: 0.8734
# 1520th iteration, loss: 0.4585, test accuracy: 0.8739
# 1530th iteration, loss: 0.4535, test accuracy: 0.8753
# 1540th iteration, loss: 0.5337, test accuracy: 0.8748
# 1550th iteration, loss: 0.5840, test accuracy: 0.8759
# 1560th iteration, loss: 0.5370, test accuracy: 0.8761
# 1570th iteration, loss: 0.5826, test accuracy: 0.8757
# 1580th iteration, loss: 0.5460, test accuracy: 0.8753
# 1590th iteration, loss: 0.5187, test accuracy: 0.8769
# 1600th iteration, loss: 0.3672, test accuracy: 0.8770
# 1610th iteration, loss: 0.4735, test accuracy: 0.8777
# 1620th iteration, loss: 0.5797, test accuracy: 0.8778
# 1630th iteration, loss: 0.4633, test accuracy: 0.8771
# 1640th iteration, loss: 0.4705, test accuracy: 0.8771
# 1650th iteration, loss: 0.6281, test accuracy: 0.8774
# 1660th iteration, loss: 0.4982, test accuracy: 0.8778
# 1670th iteration, loss: 0.4971, test accuracy: 0.8784
# 1680th iteration, loss: 0.5071, test accuracy: 0.8791
# 1690th iteration, loss: 0.3932, test accuracy: 0.8792
# 1700th iteration, loss: 0.3904, test accuracy: 0.8791
# 1710th iteration, loss: 0.4569, test accuracy: 0.8802
# 1720th iteration, loss: 0.3614, test accuracy: 0.8811
# 1730th iteration, loss: 0.3944, test accuracy: 0.8811
# 1740th iteration, loss: 0.4456, test accuracy: 0.8812
# 1750th iteration, loss: 0.5971, test accuracy: 0.8810
# 1760th iteration, loss: 0.5268, test accuracy: 0.8808
# 1770th iteration, loss: 0.4530, test accuracy: 0.8819
# 1780th iteration, loss: 0.3698, test accuracy: 0.8821
# 1790th iteration, loss: 0.5204, test accuracy: 0.8831
# 1800th iteration, loss: 0.5205, test accuracy: 0.8828
# 1810th iteration, loss: 0.3359, test accuracy: 0.8823
# 1820th iteration, loss: 0.5222, test accuracy: 0.8822
# 1830th iteration, loss: 0.4872, test accuracy: 0.8825
# 1840th iteration, loss: 0.3587, test accuracy: 0.8832
# 1850th iteration, loss: 0.5595, test accuracy: 0.8833
# 1860th iteration, loss: 0.3459, test accuracy: 0.8825
# 1870th iteration, loss: 0.4694, test accuracy: 0.8831
# 1880th iteration, loss: 0.5546, test accuracy: 0.8834
# 1890th iteration, loss: 0.5510, test accuracy: 0.8838
# 1900th iteration, loss: 0.4553, test accuracy: 0.8848
# 1910th iteration, loss: 0.4811, test accuracy: 0.8845
# 1920th iteration, loss: 0.6086, test accuracy: 0.8839
# 1930th iteration, loss: 0.5311, test accuracy: 0.8839
# 1940th iteration, loss: 0.4002, test accuracy: 0.8835
# 1950th iteration, loss: 0.4213, test accuracy: 0.8842
# 1960th iteration, loss: 0.4919, test accuracy: 0.8834
# 1970th iteration, loss: 0.3852, test accuracy: 0.8845
# 1980th iteration, loss: 0.4431, test accuracy: 0.8849
# 1990th iteration, loss: 0.3820, test accuracy: 0.8854
# 2000th iteration, loss: 0.5317, test accuracy: 0.8860
