# %% [markdown]
# # 먼저 결측치 부터 확인한다.
# isnull() 함수로 결측치 확인하고
# 좀더 쉽게보기 위해 isnull().sum()을 불러와 확인한다.
# 확인을해보니 모든 항목이 False여서 결측치가 없다고 판단했다.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.tools.eval_measures import rmse
# %matplotlib inline
matplotlib.rc('font', family='NanumBarunGothic')
plt.rcParams['axes.unicode_minus']=False

ds_Cancer = pd.read_csv("./유방암.CSV",engine="python")
print(ds_Cancer.isnull())
print(ds_Cancer.isnull().sum())
# Out:
#      diagnosis  mean radius  mean texture  mean perimeter  mean area  \
# 0        False        False         False           False      False
# 1        False        False         False           False      False
# 2        False        False         False           False      False
# 3        False        False         False           False      False
# 4        False        False         False           False      False
# 5        False        False         False           False      False
# 6        False        False         False           False      False
# 7        False        False         False           False      False
# 8        False        False         False           False      False
# 9        False        False         False           False      False
# 10       False        False         False           False      False
# 11       False        False         False           False      False
# 12       False        False         False           False      False
# ...

# %% [markdown]
# # 범주형 변수가 있는지 확인한다.
# Numeric이랑 범주형 변수랑 구분한다
# diagnosis가 목표변수이므로 y값으로 생각한다.
# 0이면 Malignant로 악성이고, 1이면 Benign으로 양성이다.

# %%
ds_Cancer
# Out:
#      diagnosis  mean radius  mean texture  mean perimeter  mean area  \
# 0            0       17.990         10.38          122.80     1001.0
# 1            0       20.570         17.77          132.90     1326.0
# 2            0       19.690         21.25          130.00     1203.0
# 3            0       11.420         20.38           77.58      386.1
# 4            0       20.290         14.34          135.10     1297.0
# 5            0       12.450         15.70           82.57      477.1
# 6            0       18.250         19.98          119.60     1040.0
# 7            0       13.710         20.83           90.20      577.9
# 8            0       13.000         21.82           87.50      519.8
# 9            0       12.460         24.04           83.97      475.9
# 10           0       16.020         23.24          102.70      797.8
# 11           0       15.780         17.89          103.60      781.0
# 12           0       19.170         24.80          132.40     1123.0
# ...

# %% [markdown]
# # diagnosis 악성 질병
# 악성 질병 데이터를 뽑았다.
# 212 명의 데이터를 색출했다.
# 양성과 악성은 범주형으로 나눠지므로, 설명변수와 목표변수의 상관관계를 위해
# 악성과 양성의 데이터셋을 나눴다.

# %%
ds_Cancer_M = ds_Cancer[ds_Cancer['diagnosis'] == 0]
ds_Cancer_M = ds_Cancer_M[ds_Cancer_M.columns[1:]]
ds_Cancer_M
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# 5          12.45         15.70           82.57      477.1          0.12780
# 6          18.25         19.98          119.60     1040.0          0.09463
# 7          13.71         20.83           90.20      577.9          0.11890
# 8          13.00         21.82           87.50      519.8          0.12730
# 9          12.46         24.04           83.97      475.9          0.11860
# 10         16.02         23.24          102.70      797.8          0.08206
# ...

# %% [markdown]
# # 양성 질병
# 양성 질병 데이터를 뽑았다. 357 명의 데이터를 색출했다

# %%
ds_Cancer_B = ds_Cancer[ds_Cancer['diagnosis'] == 1]
ds_Cancer_B = ds_Cancer_B[ds_Cancer_B.columns[1:]]
ds_Cancer_B
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 19        13.540         14.36           87.46      566.3          0.09779
# 20        13.080         15.71           85.63      520.0          0.10750
# 21         9.504         12.44           60.34      273.9          0.10240
# 37        13.030         18.42           82.61      523.8          0.08983
# 46         8.196         16.84           51.71      201.9          0.08600
# 48        12.050         14.63           78.04      449.3          0.10310
# 49        13.490         22.30           86.91      561.0          0.08752
# 50        11.760         21.60           74.72      427.9          0.08637
# 51        13.640         16.34           87.21      571.8          0.07685
# 52        11.940         18.24           75.71      437.6          0.08261
# 55        11.520         18.75           73.34      409.0          0.09524
# ...

# %%
ds_Cancer.boxplot(figsize=(20,4))
ds_Cancer.plot()

# %%
sns.pairplot(ds_Cancer)
